# %%
import numpy as np
import pandas as pd
import json

# %%
with open('t_20_json/match_results.json') as f :
    data = json.load(f) 


df_match = pd.DataFrame(data[0]['matchSummary'])
df_match
# Out:
#            team1         team2        winner      margin     ground  \
# 0        England      Pakistan       England   5 wickets  Melbourne
# 1        England         India       England  10 wickets   Adelaide
# 2    New Zealand      Pakistan      Pakistan   7 wickets     Sydney
# 3          India      Zimbabwe         India     71 runs  Melbourne
# 4     Bangladesh      Pakistan      Pakistan   5 wickets   Adelaide
# 5    Netherlands  South Africa   Netherlands     13 runs   Adelaide
# 6        England     Sri Lanka       England   4 wickets     Sydney
# 7      Australia   Afghanistan     Australia      4 runs   Adelaide
# 8        Ireland   New Zealand   New Zealand     35 runs   Adelaide
# 9       Pakistan  South Africa      Pakistan     33 runs     Sydney
# 10    Bangladesh         India         India      5 runs   Adelaide
# 11   Netherlands      Zimbabwe   Netherlands   5 wickets   Adelaide
# 12       England   New Zealand       England     20 runs   Brisbane
# ...

# %%
df_match.rename({'scorecard': 'match_id'} , axis = 1 , inplace = True)
df_match
# Out:
#            team1         team2        winner      margin     ground  \
# 0        England      Pakistan       England   5 wickets  Melbourne
# 1        England         India       England  10 wickets   Adelaide
# 2    New Zealand      Pakistan      Pakistan   7 wickets     Sydney
# 3          India      Zimbabwe         India     71 runs  Melbourne
# 4     Bangladesh      Pakistan      Pakistan   5 wickets   Adelaide
# 5    Netherlands  South Africa   Netherlands     13 runs   Adelaide
# 6        England     Sri Lanka       England   4 wickets     Sydney
# 7      Australia   Afghanistan     Australia      4 runs   Adelaide
# 8        Ireland   New Zealand   New Zealand     35 runs   Adelaide
# 9       Pakistan  South Africa      Pakistan     33 runs     Sydney
# 10    Bangladesh         India         India      5 runs   Adelaide
# 11   Netherlands      Zimbabwe   Netherlands   5 wickets   Adelaide
# 12       England   New Zealand       England     20 runs   Brisbane
# ...

# %%
df_match.to_csv('t_20_csv/dim_match_summary.csv' , index = False)

# %% [markdown]
# match_ids_dict = {}
#
# for index, row in df_match.iterrows():
#     key1 = row['team1'] + ' Vs ' + row['team2']
#     key2 = row['team2'] + ' Vs ' + row['team1']
#
#     match_ids_dict[key1] = row['match_id']
#     match_ids_dict[key2] = row['match_id']
# match_ids_dict

# %%
with open('t_20_json/batting_summary.json') as f :
    data = json.load(f)

all_records = []
for rec in data:
    all_records.extend(rec['battingSummary'])

df_batting = pd.DataFrame(all_records)
df_batting
# Out:
#                     match teamInnings  battingPos             batsmanName  \
# 0    Namibia Vs Sri Lanka     Namibia           1      Michael van Lingen
# 1    Namibia Vs Sri Lanka     Namibia           2           Divan la Cock
# 2    Namibia Vs Sri Lanka     Namibia           3  Jan Nicol Loftie-Eaton
# 3    Namibia Vs Sri Lanka     Namibia           4           Stephan Baard
# 4    Namibia Vs Sri Lanka     Namibia           5      Gerhard Erasmus(c)
# ..                    ...         ...         ...                     ...
# 694   Pakistan Vs England     England           3               Phil Salt
# 695   Pakistan Vs England     England           4              Ben Stokes
# 696   Pakistan Vs England     England           5             Harry Brook
# 697   Pakistan Vs England     England           6               Moeen Ali
# 698   Pakistan Vs England     England           7        Liam Livingstone
#
#                                dismissal runs balls 4s 6s      SR
# ...

# %%
df_batting['out/not_out'] = df_batting.dismissal.apply(lambda x: "out" if len(x) > 0 else "not_out")
df_batting.drop(columns = ['dismissal'] , inplace = True)
df_batting.head(11)
# Out:
#                    match teamInnings  battingPos             batsmanName runs  \
# 0   Namibia Vs Sri Lanka     Namibia           1      Michael van Lingen    3
# 1   Namibia Vs Sri Lanka     Namibia           2           Divan la Cock    9
# 2   Namibia Vs Sri Lanka     Namibia           3  Jan Nicol Loftie-Eaton   20
# 3   Namibia Vs Sri Lanka     Namibia           4           Stephan Baard   26
# 4   Namibia Vs Sri Lanka     Namibia           5      Gerhard Erasmus(c)   20
# 5   Namibia Vs Sri Lanka     Namibia           6            Jan Frylinck   44
# 6   Namibia Vs Sri Lanka     Namibia           7             David Wiese    0
# 7   Namibia Vs Sri Lanka     Namibia           8                 JJ Smit   31
# 8   Namibia Vs Sri Lanka   Sri Lanka           1         Pathum Nissanka    9
# 9   Namibia Vs Sri Lanka   Sri Lanka           2         Kusal Mendisâ€     6
# 10  Namibia Vs Sri Lanka   Sri Lanka           3     Dhananjaya de Silva   12
#
# ...

# %%
df_batting['batsmanName'] = df_batting['batsmanName'].apply(lambda x: x.replace('â€', ''))
df_batting['batsmanName'] = df_batting['batsmanName'].apply(lambda x: x.replace('\xa0', ''))
df_batting.head(11)
# Out:
#                    match teamInnings  battingPos             batsmanName runs  \
# 0   Namibia Vs Sri Lanka     Namibia           1      Michael van Lingen    3
# 1   Namibia Vs Sri Lanka     Namibia           2           Divan la Cock    9
# 2   Namibia Vs Sri Lanka     Namibia           3  Jan Nicol Loftie-Eaton   20
# 3   Namibia Vs Sri Lanka     Namibia           4           Stephan Baard   26
# 4   Namibia Vs Sri Lanka     Namibia           5      Gerhard Erasmus(c)   20
# 5   Namibia Vs Sri Lanka     Namibia           6            Jan Frylinck   44
# 6   Namibia Vs Sri Lanka     Namibia           7             David Wiese    0
# 7   Namibia Vs Sri Lanka     Namibia           8                 JJ Smit   31
# 8   Namibia Vs Sri Lanka   Sri Lanka           1         Pathum Nissanka    9
# 9   Namibia Vs Sri Lanka   Sri Lanka           2            Kusal Mendis    6
# 10  Namibia Vs Sri Lanka   Sri Lanka           3     Dhananjaya de Silva   12
#
# ...

# %%
df_batting["match_id"] = df_batting["match"].map(match_ids_dict)
df_batting.head(50)
# Out:
#                       match  teamInnings  battingPos  \
# 0      Namibia Vs Sri Lanka      Namibia           1
# 1      Namibia Vs Sri Lanka      Namibia           2
# 2      Namibia Vs Sri Lanka      Namibia           3
# 3      Namibia Vs Sri Lanka      Namibia           4
# 4      Namibia Vs Sri Lanka      Namibia           5
# 5      Namibia Vs Sri Lanka      Namibia           6
# 6      Namibia Vs Sri Lanka      Namibia           7
# 7      Namibia Vs Sri Lanka      Namibia           8
# 8      Namibia Vs Sri Lanka    Sri Lanka           1
# 9      Namibia Vs Sri Lanka    Sri Lanka           2
# 10     Namibia Vs Sri Lanka    Sri Lanka           3
# 11     Namibia Vs Sri Lanka    Sri Lanka           4
# 12     Namibia Vs Sri Lanka    Sri Lanka           5
# 13     Namibia Vs Sri Lanka    Sri Lanka           6
# 14     Namibia Vs Sri Lanka    Sri Lanka           7
# 15     Namibia Vs Sri Lanka    Sri Lanka           8
# 16     Namibia Vs Sri Lanka    Sri Lanka           9
# ...

# %%
df_batting.to_csv('t_20_csv/fact_batting_summary.csv' , index = False)

# %%
with open('t_20_json/bowling_summary.json') as f: 
    data = json.load(f)
all_records = [] 

for rec in data:
    all_records.extend(rec["bowlingSummary"])

df_bowling = pd.DataFrame(all_records)
df_bowling
# Out:
#                     match bowlingTeam                  bowlerName overs  \
# 0    Namibia Vs Sri Lanka   Sri Lanka          Maheesh Theekshana     4
# 1    Namibia Vs Sri Lanka   Sri Lanka         Dushmantha Chameera     4
# 2    Namibia Vs Sri Lanka   Sri Lanka             Pramod Madushan     4
# 3    Namibia Vs Sri Lanka   Sri Lanka         Chamika Karunaratne     4
# 4    Namibia Vs Sri Lanka   Sri Lanka  Wanindu Hasaranga de Silva     4
# ..                    ...         ...                         ...   ...
# 495   Pakistan Vs England    Pakistan                 Naseem Shah     4
# 496   Pakistan Vs England    Pakistan                  Haris Rauf     4
# 497   Pakistan Vs England    Pakistan                 Shadab Khan     4
# 498   Pakistan Vs England    Pakistan              Mohammad Wasim     4
# 499   Pakistan Vs England    Pakistan              Iftikhar Ahmed   0.5
#
#     maiden runs wickets economy  0s 4s 6s wides noBalls
# ...

# %%
df_bowling["match_id"] = df_bowling["match"].map(match_ids_dict)
df_bowling.head(20)
# Out:
#                     match  bowlingTeam                  bowlerName overs  \
# 0    Namibia Vs Sri Lanka    Sri Lanka          Maheesh Theekshana     4
# 1    Namibia Vs Sri Lanka    Sri Lanka         Dushmantha Chameera     4
# 2    Namibia Vs Sri Lanka    Sri Lanka             Pramod Madushan     4
# 3    Namibia Vs Sri Lanka    Sri Lanka         Chamika Karunaratne     4
# 4    Namibia Vs Sri Lanka    Sri Lanka  Wanindu Hasaranga de Silva     4
# 5    Namibia Vs Sri Lanka      Namibia             Gerhard Erasmus     1
# 6    Namibia Vs Sri Lanka      Namibia                 David Wiese     4
# 7    Namibia Vs Sri Lanka      Namibia             Bernard Scholtz     4
# 8    Namibia Vs Sri Lanka      Namibia                Ben Shikongo     3
# 9    Namibia Vs Sri Lanka      Namibia                     JJ Smit     3
# 10   Namibia Vs Sri Lanka      Namibia                Jan Frylinck     4
# 11  U.A.E. Vs Netherlands  Netherlands               Fred Klaassen     4
# ...

# %%
df_bowling.to_csv('t_20_csv/fact_bowling_summary.csv' , index = False)

# %%
with open('t_20_json/player_info.json') as f:
    data = json.load(f)

# %%
df_players = pd.DataFrame(data)
df_players.head(40)
# Out:
#                           name       team    battingStyle  \
# 0           Michael van Lingen    Namibia   Left hand Bat
# 1                Divan la Cock    Namibia  Right hand Bat
# 2       Jan Nicol Loftie-Eaton    Namibia   Left hand Bat
# 3                Stephan Baard    Namibia  Right hand Bat
# 4           Gerhard Erasmus(c)    Namibia  Right hand Bat
# 5                 Jan Frylinck    Namibia   Left hand Bat
# 6                  David Wiese    Namibia  Right hand Bat
# 7                      JJ Smit    Namibia  Right hand Bat
# 8              Pathum Nissanka  Sri Lanka  Right hand Bat
# 9              Kusal Mendisâ€   Sri Lanka  Right hand Bat
# 10         Dhananjaya de Silva  Sri Lanka  Right hand Bat
# 11        Danushka Gunathilaka  Sri Lanka   Left hand Bat
# 12           Bhanuka Rajapaksa  Sri Lanka   Left hand Bat
# 13            Dasun Shanaka(c)  Sri Lanka  Right hand Bat
# 14  Wanindu Hasaranga de Silva  Sri Lanka  Right hand Bat
# ...

# %%
df_players['name'] = df_players['name'].apply(lambda x: x.replace('â€', ''))
df_players['name'] = df_players['name'].apply(lambda x: x.replace('†', ''))
df_players['name'] = df_players['name'].apply(lambda x: x.replace('\xa0', ''))
df_players.head(10)
# Out:
#                      name       team    battingStyle  \
# 0      Michael van Lingen    Namibia   Left hand Bat
# 1           Divan la Cock    Namibia  Right hand Bat
# 2  Jan Nicol Loftie-Eaton    Namibia   Left hand Bat
# 3           Stephan Baard    Namibia  Right hand Bat
# 4      Gerhard Erasmus(c)    Namibia  Right hand Bat
# 5            Jan Frylinck    Namibia   Left hand Bat
# 6             David Wiese    Namibia  Right hand Bat
# 7                 JJ Smit    Namibia  Right hand Bat
# 8         Pathum Nissanka  Sri Lanka  Right hand Bat
# 9            Kusal Mendis  Sri Lanka  Right hand Bat
#
#                  bowlingStyle          playingRole  \
# 0             Left arm Medium   Bowling Allrounder
# 1                    Legbreak       Opening Batter
# 2  Right arm Medium, Legbreak               Batter
# 3       Right arm Medium fast               Batter
# 4          Right arm Offbreak           Allrounder
# 5        Left arm Fast medium           Allrounder
# ...

# %%
df_players.to_csv('t_20_csv/dim_player_no_images.csv', index = False)
